# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('http://bit.ly/w-data')

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
sns.scatterplot(x=df['Scores'],y=df['Hours'])
# Out:
# <AxesSubplot:xlabel='Scores', ylabel='Hours'>

# %%
x=df[['Hours']]
y=df[['Scores']]

# %%
y
# Out:
#     Scores
# 0       21
# 1       47
# 2       27
# 3       75
# 4       30
# 5       20
# 6       88
# 7       60
# 8       81
# 9       25
# 10      85
# 11      62
# 12      41
# 13      42
# 14      17
# 15      95
# 16      30
# 17      24
# 18      67
# 19      69
# 20      30
# 21      54
# 22      35
# 23      76
# 24      86

# %%
sns.lineplot(x='Hours',y='Scores',data=df)
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Scores'>

# %%
sns.lmplot(x='Hours',y='Scores',data=df)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
X_test
# Out:
#     Hours
# 5     1.5
# 2     3.2
# 19    7.4
# 16    2.5
# 11    5.9
# 22    3.8
# 17    1.9
# 24    7.8

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(X_test)
pred
# Out:
# array([[17.05366541],
#        [33.69422878],
#        [74.80620886],
#        [26.8422321 ],
#        [60.12335883],
#        [39.56736879],
#        [20.96909209],
#        [78.72163554]])

# %%
print('For training data')
print(lr.score(X_train,y_train))

print('For testing data')
print(lr.score(X_test,y_test))

print('For predicted data')
print(lr.score(X_test,pred))
# Out:
# For training data
# 0.9484997422695115
# For testing data
# 0.9568211104435257
# For predicted data
# 1.0

# %%
ans=lr.predict([[9.25]])
print('9.25hrs of studying will give a score of ',ans[0])
# Out:
# 9.25hrs of studying will give a score of  [92.91505723]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print('Mean Squared Error->',mean_squared_error(y_test,pred))
print('Mean Absolute Error->',mean_absolute_error(y_test,pred))
# Out:
# Mean Squared Error-> 22.965097212700428
# Mean Absolute Error-> 4.419727808027651
